# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
xray_dataset = pd.read_csv("C:\\Users\\Death Fighter\\Desktop\\Thesis\\Thesis\\Chest_XRAY\\Dataset\\csv files\\chestxray.csv")
xray_dataset.head()
# Out:
#    Unnamed: 0       Image Index  Labels  Mark  Patient ID  Patient Age  \
# 0           0  00000001_000.png       1     0           1           58
# 1           1  00000001_001.png       1     1           1           58
# 2           2  00000001_002.png       1     2           1           58
# 3           3  00000002_000.png       0     0           2           81
# 4           4  00000003_000.png       1     0           3           81
#
#   Patient Gender View Position  OriginalImage[Width  Height]  \
# 0              M            PA                 2682     2749
# 1              M            PA                 2894     2729
# 2              M            PA                 2500     2048
# 3              M            PA                 2500     2048
# 4              F            PA                 2582     2991
#
#    OriginalImagePixelSpacing[x     y]
# 0                        0.143  0.143
# 1                        0.143  0.143
# 2                        0.168  0.168
# ...

# %%
print(xray_dataset.shape)
print("Rows in the Data Set: ",xray_dataset.shape[0])
print("Columns in the Data Set: ",xray_dataset.shape[1])
# Out:
# (112120, 12)
# Rows in the Data Set:  112120
# Columns in the Data Set:  12

# %%
list(xray_dataset.columns)[1:]
# Out:
# ['Image Index',
#  'Labels',
#  'Mark',
#  'Patient ID',
#  'Patient Age',
#  'Patient Gender',
#  'View Position',
#  'OriginalImage[Width',
#  'Height]',
#  'OriginalImagePixelSpacing[x',
#  'y]']

# %%
xray_dataset.describe()
# Out:
#           Unnamed: 0         Labels           Mark     Patient ID  \
# count  112120.000000  112120.000000  112120.000000  112120.000000
# mean    56059.500000       0.461639       8.573751   14346.381743
# std     32366.400428       0.498529      15.406320    8403.876972
# min         0.000000       0.000000       0.000000       1.000000
# 25%     28029.750000       0.000000       0.000000    7310.750000
# 50%     56059.500000       0.000000       3.000000   13993.000000
# 75%     84089.250000       1.000000      10.000000   20673.000000
# max    112119.000000       1.000000     183.000000   30805.000000
#
#          Patient Age  OriginalImage[Width        Height]  \
# count  112120.000000        112120.000000  112120.000000
# mean       46.901463          2646.078844    2486.438842
# std        16.839923           341.246429     401.268227
# min         1.000000          1143.000000     966.000000
# 25%        35.000000          2500.000000    2048.000000
# ...

# %%
sns.set_style('whitegrid')
sns.countplot(x='View Position',data=xray_dataset,palette='dark')

# %%
sns.set_style('whitegrid')
sns.countplot(x='Labels',data=xray_dataset,palette='hls')

# %%
sns.set_style('whitegrid')
sns.countplot(x='Patient Gender',data=xray_dataset,palette='Spectral')

# %%
xray_dataset.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019C0F95D4C8>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(xray_dataset.corr(),annot=True,cmap="Spectral")

# %%
for k,v in xray_dataset.corr()['Labels'].items():
    if k!="Labels" and k!="Unnamed: 0":
        print(k,">>>",v)
# Out:
# Mark >>> 0.17614345518309096
# Patient ID >>> 0.051920214849458586
# Patient Age >>> 0.07278885571243424
# OriginalImage[Width >>> 0.06519953057630563
# Height] >>> -0.01185566301013595
# OriginalImagePixelSpacing[x >>> -0.03586107379606298
# y] >>> -0.03586107379606298
